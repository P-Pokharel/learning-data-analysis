# %% [markdown]
# # Reading HTML Table

# %%
import pandas as pd
from io import StringIO

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# # Parsing raw HTML string

# %%
html_string = """
<table>
    <thead>
      <tr>
        <th>Order date</th>
        <th>Region</th> 
        <th>Item</th>
        <th>Units</th>
        <th>Unit cost</th>
      </tr>
    </thead>
    <tbody>
      <tr>
        <td>1/6/2018</td>
        <td>East</td> 
        <td>Pencil</td>
        <td>95</td>
        <td>1.99</td>
      </tr>
      <tr>
        <td>1/23/2018</td>
        <td>Central</td> 
        <td>Binder</td>
        <td>50</td>
        <td>19.99</td>
      </tr>
      <tr>
        <td>2/9/2018</td>
        <td>Central</td> 
        <td>Pencil</td>
        <td>36</td>
        <td>4.99</td>
      </tr>
      <tr>
        <td>3/15/2018</td>
        <td>West</td> 
        <td>Pen</td>
        <td>27</td>
        <td>19.99</td>
      </tr>
    </tbody>
</table>
"""

# %%
from IPython.core.display import display, HTML
display(HTML(html_string))
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_4584\149234223.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <table>
#     <thead>
#       <tr>
#         <th>Order date</th>
#         <th>Region</th>
#         <th>Item</th>
#         <th>Units</th>
#         <th>Unit cost</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
#         <td>1/6/2018</td>
#         <td>East</td>
#         <td>Pencil</td>
#         <td>95</td>
#         <td>1.99</td>
#       </tr>
#       <tr>
#         <td>1/23/2018</td>
#         <td>Central</td>
#         <td>Binder</td>
#         <td>50</td>
#         <td>19.99</td>
#       </tr>
#       <tr>
#         <td>2/9/2018</td>
#         <td>Central</td>
#         <td>Pencil</td>
#         <td>36</td>
#         <td>4.99</td>
#       </tr>
#       <tr>
#         <td>3/15/2018</td>
#         <td>West</td>
#         <td>Pen</td>
#         <td>27</td>
#         <td>19.99</td>
#       </tr>
#     </tbody>
# </table>

# %%
dfs = pd.read_html(StringIO(html_string))

# %%
dfs
# Out:
# [  Order date   Region    Item  Units  Unit cost
#  0   1/6/2018     East  Pencil     95       1.99
#  1  1/23/2018  Central  Binder     50      19.99
#  2   2/9/2018  Central  Pencil     36       4.99
#  3  3/15/2018     West     Pen     27      19.99]

# %%
len(dfs)
# Out:
# 1

# %%
df = dfs[0]
df
# Out:
#   Order date   Region    Item  Units  Unit cost
# 0   1/6/2018     East  Pencil     95       1.99
# 1  1/23/2018  Central  Binder     50      19.99
# 2   2/9/2018  Central  Pencil     36       4.99
# 3  3/15/2018     West     Pen     27      19.99

# %%
df.shape
# Out:
# (4, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order date  4 non-null      object
#  1   Region      4 non-null      object
#  2   Item        4 non-null      object
#  3   Units       4 non-null      int64
#  4   Unit cost   4 non-null      float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 292.0+ bytes

# %%
df.loc[df['Region'] == 'Central']
# Out:
#   Order date   Region    Item  Units  Unit cost
# 1  1/23/2018  Central  Binder     50      19.99
# 2   2/9/2018  Central  Pencil     36       4.99

# %%
df.loc[df['Units'] > 35]
# Out:
#   Order date   Region    Item  Units  Unit cost
# 0   1/6/2018     East  Pencil     95       1.99
# 1  1/23/2018  Central  Binder     50      19.99
# 2   2/9/2018  Central  Pencil     36       4.99

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ### Defining Headers

# %%
html_string = """
<table>
  <tr>
    <td>Order date</td>
    <td>Region</td> 
    <td>Item</td>
    <td>Units</td>
    <td>Unit cost</td>
  </tr>
  <tr>
    <td>1/6/2018</td>
    <td>East</td> 
    <td>Pencil</td>
    <td>95</td>
    <td>1.99</td>
  </tr>
  <tr>
    <td>1/23/2018</td>
    <td>Central</td> 
    <td>Binder</td>
    <td>50</td>
    <td>19.99</td>
  </tr>
  <tr>
    <td>2/9/2018</td>
    <td>Central</td> 
    <td>Pencil</td>
    <td>36</td>
    <td>4.99</td>
  </tr>
  <tr>
    <td>3/15/2018</td>
    <td>West</td> 
    <td>Pen</td>
    <td>27</td>
    <td>19.99</td>
  </tr>
</table>
"""

# %%
pd.read_html(StringIO(html_string))[0]
# Out:
#             0        1       2      3          4
# 0  Order date   Region    Item  Units  Unit cost
# 1    1/6/2018     East  Pencil     95       1.99
# 2   1/23/2018  Central  Binder     50      19.99
# 3    2/9/2018  Central  Pencil     36       4.99
# 4   3/15/2018     West     Pen     27      19.99

# %%
pd.read_html(StringIO(html_string), header=0)[0]
# Out:
#   Order date   Region    Item  Units  Unit cost
# 0   1/6/2018     East  Pencil     95       1.99
# 1  1/23/2018  Central  Binder     50      19.99
# 2   2/9/2018  Central  Pencil     36       4.99
# 3  3/15/2018     West     Pen     27      19.99

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# # Parsing HTML tables from web

# %%
html_url = 'https://www.basketball-reference.com/leagues/NBA_2024_per_game.html'

# %%
nba_tables = pd.read_html(html_url)

# %%
len(nba_tables)
# Out:
# 1

# %%
nba = nba_tables[0]

# %%
nba.head()
# Out:
#   Rk            Player   Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 0  1  Precious Achiuwa  PF-C  24  TOT  74  18  21.9  3.2   6.3  ...  .616
# 1  1  Precious Achiuwa     C  24  TOR  25   0  17.5  3.1   6.8  ...  .571
# 2  1  Precious Achiuwa    PF  24  NYK  49  18  24.2  3.2   6.1  ...  .643
# 3  2       Bam Adebayo     C  26  MIA  71  71  34.0  7.5  14.3  ...  .755
# 4  3      Ochai Agbaji    SG  23  TOT  78  28  21.0  2.3   5.6  ...  .661
#
#    ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0  2.6  4.0   6.6  1.3  0.6  0.9  1.1  1.9   7.6
# 1  2.0  3.4   5.4  1.8  0.6  0.5  1.2  1.6   7.7
# 2  2.9  4.3   7.2  1.1  0.6  1.1  1.1  2.1   7.6
# 3  2.2  8.1  10.4  3.9  1.1  0.9  2.3  2.2  19.3
# 4  0.9  1.8   2.8  1.1  0.6  0.6  0.8  1.5   5.8
#
# [5 rows x 30 columns]

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ### Getting HTML code from an URL to parse it into DataFrame objects.

# %%
import requests

# %%
html_url = 'https://en.wikipedia.org/wiki/The_Simpsons'

# %%
r = requests.get(html_url)

# %%
wiki_tables = pd.read_html(StringIO(r.text), header=0)

# %%
len(wiki_tables)
# Out:
# 48

# %%
simpsons = wiki_tables[2]

# %%
simpsons.head()
# Out:
#    Season Season.1  No. of episodes    Originally aired Originally aired.1  \
# 0  Season   Season  No. of episodes     Season premiere      Season finale
# 1  Season   Season  No. of episodes     Season premiere      Season finale
# 2       1  1989–90               13   December 17, 1989       May 13, 1990
# 3       2  1990–91               22    October 11, 1990      July 11, 1991
# 4       3  1991–92               24  September 19, 1991    August 27, 1992
#
#   Originally aired.2                  Viewership          Viewership.1  \
# 0     Time slot (ET)  Avg. viewers (in millions)  Most watched episode
# 1     Time slot (ET)  Avg. viewers (in millions)    Viewers (millions)
# 2     Sunday 8:30 pm                        27.8             33.5[168]
# 3   Thursday 8:00 pm                        24.4             33.6[169]
# 4   Thursday 8:00 pm                        21.8             25.5[170]
#
#               Viewership.2
# 0     Most watched episode
# 1            Episode title
# 2  "Life on the Fast Lane"
# 3       "Bart Gets an 'F'"
# 4          "Colonel Homer"

# %%
simpsons.columns = simpsons.iloc[1]

# %%
simpsons.head()
# Out:
# 1  Season   Season  No. of episodes     Season premiere    Season finale  \
# 0  Season   Season  No. of episodes     Season premiere    Season finale
# 1  Season   Season  No. of episodes     Season premiere    Season finale
# 2       1  1989–90               13   December 17, 1989     May 13, 1990
# 3       2  1990–91               22    October 11, 1990    July 11, 1991
# 4       3  1991–92               24  September 19, 1991  August 27, 1992
#
# 1    Time slot (ET)  Avg. viewers (in millions)    Viewers (millions)  \
# 0    Time slot (ET)  Avg. viewers (in millions)  Most watched episode
# 1    Time slot (ET)  Avg. viewers (in millions)    Viewers (millions)
# 2    Sunday 8:30 pm                        27.8             33.5[168]
# 3  Thursday 8:00 pm                        24.4             33.6[169]
# 4  Thursday 8:00 pm                        21.8             25.5[170]
#
# 1            Episode title
# 0     Most watched episode
# 1            Episode title
# 2  "Life on the Fast Lane"
# 3       "Bart Gets an 'F'"
# 4          "Colonel Homer"

# %%
simpsons.drop([0, 1], inplace=True)

# %%
simpsons.head()
# Out:
# 1 Season   Season No. of episodes     Season premiere    Season finale  \
# 2      1  1989–90              13   December 17, 1989     May 13, 1990
# 3      2  1990–91              22    October 11, 1990    July 11, 1991
# 4      3  1991–92              24  September 19, 1991  August 27, 1992
# 5      4  1992–93              22  September 24, 1992     May 13, 1993
# 6      5  1993–94              22  September 30, 1993     May 19, 1994
#
# 1    Time slot (ET) Avg. viewers (in millions) Viewers (millions)  \
# 2    Sunday 8:30 pm                       27.8          33.5[168]
# 3  Thursday 8:00 pm                       24.4          33.6[169]
# 4  Thursday 8:00 pm                       21.8          25.5[170]
# 5  Thursday 8:00 pm                       22.4          28.6[171]
# 6  Thursday 8:00 pm                       18.9          24.0[172]
#
# 1             Episode title
# 2   "Life on the Fast Lane"
# 3        "Bart Gets an 'F'"
# 4           "Colonel Homer"
# 5       "Lisa's First Word"
# 6  "Treehouse of Horror IV"

# %%
# (17, 2005–06)                                       Sunday 8:00 pm
# (18, 2006–07)                                       Sunday 8:00 pm
# (19, 2007–08)                                       Sunday 8:00 pm
# (20, 2008–09)    Sunday 8:00 pm (Episodes 1–7, 9–21) Sunday 8:3...
# (21, 2009–10)                                       Sunday 8:00 pm
# (22, 2010–11)                                       Sunday 8:00 pm
# (23, 2011–12)                                       Sunday 8:00 pm
# (24, 2012–13)    Sunday 8:00 pm (Episodes 1–21) Sunday 8:30 pm ...
# (25, 2013–14)    Sunday 8:00 pm (Episodes 1–11, 13–22) Sunday 7...
# (26, 2014–15)                                       Sunday 8:00 pm
# (27, 2015–16)                                       Sunday 8:00 pm
# (28, 2016–17)                                       Sunday 8:00 pm
# (29, 2017–18)                                       Sunday 8:00 pm
# (30, 2018–19)                                       Sunday 8:00 pm
# (31, 2019–20)                                       Sunday 8:00 pm
# (32, 2020–21)    Sunday 8:00 pm (Episodes 1–10, 12–22) Sunday 9...
# (33, 2021–22)    Sunday 8:00 pm (Episodes 1–10, 12–22) Sunday 9...
# (34, 2022–23)    Sunday 8:00 pm (Episodes 1–8, 10–22) Sunday 8:...
# (35, 2023–24)    Sunday 8:00 pm (Episodes 1–5, 7, 10–18) Sunday...
#
# 1               Avg. viewers (in millions) Viewers (millions)  \
# Season
# (1, 1989–90)                          27.8          33.5[168]
# (2, 1990–91)                          24.4          33.6[169]
# (3, 1991–92)                          21.8          25.5[170]
# (4, 1992–93)                          22.4          28.6[171]
# (5, 1993–94)                          18.9          24.0[172]
# (6, 1994–95)                          15.6          22.2[173]
# (7, 1995–96)                          15.1          22.6[174]
# (8, 1996–97)                          14.5         20.41[176]
# (9, 1997–98)                          15.3         19.80[177]
# (10, 1998–99)                         13.5         19.11[178]
# (11, 1999–2000)                        8.8         19.16[179]
# (12, 2000–01)                         15.5         18.52[180]
# (13, 2001–02)                         12.5         14.91[181]
# (14, 2002–03)                         14.4         22.04[182]
# (15, 2003–04)                         11.0         16.30[183]
# (16, 2004–05)                         10.2         23.07[184]
# (17, 2005–06)                         9.55         11.66[185]
# (18, 2006–07)                         9.15         11.63[186]
# (19, 2007–08)                         8.37         11.74[187]
# (20, 2008–09)                          7.1         12.40[188]
# (21, 2009–10)                          7.1         14.62[189]
# (22, 2010–11)                         7.09         12.55[190]
# (23, 2011–12)                    6.15[191]         11.48[192]
# (24, 2012–13)                    5.41[193]          8.97[194]
# (25, 2013–14)                    5.02[195]         12.04[196]
# (26, 2014–15)                    5.61[197]         10.62[198]
# (27, 2015–16)                     4.0[199]          8.33[200]
# (28, 2016–17)                    4.80[201]          8.19[202]
# (29, 2017–18)                    4.07[203]          8.04[204]
# (30, 2018–19)                    3.10[205]          8.20[206]
# (31, 2019–20)                    2.58[207]          5.63[208]
# (32, 2020–21)                    2.32[209]          4.93[210]
# (33, 2021–22)                    2.25[211]          3.97[212]
# (34, 2022–23)                    1.83[213]          4.77[214]
# (35, 2023–24)                          TBA                TBA
#
# 1                                               Episode title
# Season
# (1, 1989–90)                          "Life on the Fast Lane"
# (2, 1990–91)                               "Bart Gets an 'F'"
# (3, 1991–92)                                  "Colonel Homer"
# (4, 1992–93)                              "Lisa's First Word"
# (5, 1993–94)                         "Treehouse of Horror IV"
# (6, 1994–95)                          "Treehouse of Horror V"
# (7, 1995–96)                  "Who Shot Mr. Burns? – Part II"
# (8, 1996–97)                          "The Springfield Files"
# (9, 1997–98)               "The Two Mrs. Nahasapeemapetilons"
# (10, 1998–99)                         "Sunday, Cruddy Sunday"
# (11, 1999–2000)                                   "Faith Off"
# (12, 2000–01)                                          "HOMR"
# (13, 2001–02)                                "The Parent Rap"
# (14, 2002–03)                 "I'm Spelling as Fast as I Can"
# (15, 2003–04)                        "I, (Annoyed Grunt)-Bot"
# (16, 2004–05)                "Homer and Ned's Hail Mary Pass"
# (17, 2005–06)                       "Treehouse of Horror XVI"
# (18, 2006–07)    "The Mook, the Chef, the Wife and Her Homer"
# (19, 2007–08)                     "Treehouse of Horror XVIII"
# (20, 2008–09)                       "Treehouse of Horror XIX"
# (21, 2009–10)               "Once Upon a Time in Springfield"
# (22, 2010–11)                       "Moms I'd Like to Forget"
# (23, 2011–12)                         "The D'oh-cial Network"
# (24, 2012–13)                     "Homer Goes to Prep School"
# (25, 2013–14)                            "Steal This Episode"
# (26, 2014–15)                 "The Man Who Came to Be Dinner"
# (27, 2015–16)            "Teenage Mutant Milk-Caused Hurdles"
# (28, 2016–17)                                "Pork and Burns"
# (29, 2017–18)                              "Frink Gets Testy"
# (30, 2018–19)                           "The Girl on the Bus"
# (31, 2019–20)                            "Go Big or Go Homer"
# (32, 2020–21)                      "Treehouse of Horror XXXI"
# (33, 2021–22)                  "Portrait of a Lackey on Fire"
# (34, 2022–23)                        "From Beer to Paternity"
# (35, 2023–24)                                             TBA

# %%
simpsons.head()
# Out:
# 1            No. of episodes     Season premiere    Season finale  \
# Season
# (1, 1989–90)              13   December 17, 1989     May 13, 1990
# (2, 1990–91)              22    October 11, 1990    July 11, 1991
# (3, 1991–92)              24  September 19, 1991  August 27, 1992
# (4, 1992–93)              22  September 24, 1992     May 13, 1993
# (5, 1993–94)              22  September 30, 1993     May 19, 1994
#
# 1               Time slot (ET) Avg. viewers (in millions) Viewers (millions)  \
# Season
# (1, 1989–90)    Sunday 8:30 pm                       27.8          33.5[168]
# (2, 1990–91)  Thursday 8:00 pm                       24.4          33.6[169]
# (3, 1991–92)  Thursday 8:00 pm                       21.8          25.5[170]
# (4, 1992–93)  Thursday 8:00 pm                       22.4          28.6[171]
# (5, 1993–94)  Thursday 8:00 pm                       18.9          24.0[172]
#
# 1                        Episode title
# Season
# (1, 1989–90)   "Life on the Fast Lane"
# (2, 1990–91)        "Bart Gets an 'F'"
# (3, 1991–92)           "Colonel Homer"
# (4, 1992–93)       "Lisa's First Word"
# (5, 1993–94)  "Treehouse of Horror IV"

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ### Saving to the CSV

# %%
simpsons.to_csv('data/simpsons.csv')

# %%
new_csv = pd.read_csv('data/simpsons.csv')

# %%
new_csv.drop(columns=new_csv.columns[0], axis=1)
# Out:
#     Season   Season.1  No. of episodes     Season premiere    Season finale  \
# 0        1    1989–90               13   December 17, 1989     May 13, 1990
# 1        2    1990–91               22    October 11, 1990    July 11, 1991
# 26                                     Sunday 8:00 pm
# 27                                     Sunday 8:00 pm
# 28                                     Sunday 8:00 pm
# 29                                     Sunday 8:00 pm
# 30                                     Sunday 8:00 pm
# 31  Sunday 8:00 pm (Episodes 1–10, 12–22) Sunday 9...
# 32  Sunday 8:00 pm (Episodes 1–10, 12–22) Sunday 9...
# 33  Sunday 8:00 pm (Episodes 1–8, 10–22) Sunday 8:...
# 34  Sunday 8:00 pm (Episodes 1–5, 7, 10–18) Sunday...
#
#    Avg. viewers (in millions) Viewers (millions)  \
# 0                        27.8          33.5[168]
# 1                        24.4          33.6[169]
# 2                        21.8          25.5[170]
# 3                        22.4          28.6[171]
# 4                        18.9          24.0[172]
# 5                        15.6          22.2[173]
# 6                        15.1          22.6[174]
# 7                        14.5         20.41[176]
# 8                        15.3         19.80[177]
# 9                        13.5         19.11[178]
# 10                        8.8         19.16[179]
# 11                       15.5         18.52[180]
# 12                       12.5         14.91[181]
# 13                       14.4         22.04[182]
# 14                       11.0         16.30[183]
# 15                       10.2         23.07[184]
# 16                       9.55         11.66[185]
# 17                       9.15         11.63[186]
# 18                       8.37         11.74[187]
# 19                        7.1         12.40[188]
# 20                        7.1         14.62[189]
# 21                       7.09         12.55[190]
# 22                  6.15[191]         11.48[192]
# 23                  5.41[193]          8.97[194]
# 24                  5.02[195]         12.04[196]
# 25                  5.61[197]         10.62[198]
# 26                   4.0[199]          8.33[200]
# 27                  4.80[201]          8.19[202]
# 28                  4.07[203]          8.04[204]
# 29                  3.10[205]          8.20[206]
# 30                  2.58[207]          5.63[208]
# 31                  2.32[209]          4.93[210]
# 32                  2.25[211]          3.97[212]
# 33                  1.83[213]          4.77[214]
# 34                        TBA                TBA
#
#                                    Episode title
# 0                        "Life on the Fast Lane"
# 1                             "Bart Gets an 'F'"
# 2                                "Colonel Homer"
# 3                            "Lisa's First Word"
# 4                       "Treehouse of Horror IV"
# 5                        "Treehouse of Horror V"
# 6                "Who Shot Mr. Burns? – Part II"
# 7                        "The Springfield Files"
# 8             "The Two Mrs. Nahasapeemapetilons"
# 9                        "Sunday, Cruddy Sunday"
# 10                                   "Faith Off"
# 11                                        "HOMR"
# 12                              "The Parent Rap"
# 13               "I'm Spelling as Fast as I Can"
# 14                      "I, (Annoyed Grunt)-Bot"
# 15              "Homer and Ned's Hail Mary Pass"
# 16                     "Treehouse of Horror XVI"
# 17  "The Mook, the Chef, the Wife and Her Homer"
# 18                   "Treehouse of Horror XVIII"
# 19                     "Treehouse of Horror XIX"
# 20             "Once Upon a Time in Springfield"
# 21                     "Moms I'd Like to Forget"
# 22                       "The D'oh-cial Network"
# 23                   "Homer Goes to Prep School"
# 24                          "Steal This Episode"
# 25               "The Man Who Came to Be Dinner"
# 26          "Teenage Mutant Milk-Caused Hurdles"
# 27                              "Pork and Burns"
# 28                            "Frink Gets Testy"
# 29                         "The Girl on the Bus"
# 30                          "Go Big or Go Homer"
# 31                    "Treehouse of Horror XXXI"
# 32                "Portrait of a Lackey on Fire"
# 33                      "From Beer to Paternity"
# 34                                           TBA

# %%
new_csv = new_csv.drop(columns=new_csv.columns[0], axis=1)

# %%
new_csv.to_csv('data/simpsons.csv')
